# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)"

reg2 = requests.get(url).text

# %%
soup = BeautifulSoup(reg2, "html.parser")

# %%
rows_label = soup.find_all("table")[0]

# %%
rows = rows_label.find_all("th")
rows_items = [row.text.strip() for row in rows][:6]

# %%
rows_items
# Out:
# ['Country / Area',
#  'UN continentalregion[4]',
#  'UN statisticalsubregion[4]',
#  'Population(1 July 2022)',
#  'Population(1 July 2023)',
#  'Change']

# %%
df = pd.DataFrame(columns = rows_items)
df
# Out:
# Empty DataFrame
# Columns: [Country / Area, UN continentalregion[4], UN statisticalsubregion[4], Population(1 July 2022), Population(1 July 2023), Change]
# Index: []

# %%
labels = rows_label.find("tbody")
labels_items = [label.text for label in labels][2:]
labels_item = [labels.strip("\n\xa0\n") for labels in labels_items]
labels_item2 = [label2.split("\n") for label2 in labels_item if label2 != '']

# %%
labels_item2[3]
# Out:
# ['Indonesia',
#  'Asia',
#  'Southeastern Asia',
#  '275,501,339',
#  '277,534,123',
#  '+0.74%']

# %%
for x in labels_item2:
    length = len(df)
    df.loc[length] = x
df
# Out:
#                         Country / Area UN continentalregion[4]  \
# 0                                India                    Asia
# 1                             China[a]                    Asia
# 2                     United States[b]           North America
# 3                            Indonesia                    Asia
# 4                             Pakistan                    Asia
# ..                                 ...                     ...
# 469        Montserrat (United Kingdom)                Americas
# 470  Falkland Islands (United Kingdom)                Americas
# 471                 Niue (New Zealand)                 Oceania
# 472              Tokelau (New Zealand)                 Oceania
# 473                              World
#
#     UN statisticalsubregion[4] Population(1 July 2022)  \
# 0                Southern Asia           1,417,173,173
# 1                 Eastern Asia           1,425,887,337
# 2             Northern America             338,289,857
# 3            Southeastern Asia             275,501,339
# 4                Southern Asia             235,824,863
# ..                         ...                     ...
# 469                  Caribbean                   4,390
# 470           Southern America                   3,780
# 471                  Polynesia                   1,934
# 472                  Polynesia                   1,871
# 473                                      7,975,105,156
#
#     Population(1 July 2023)  Change
# 0             1,428,627,663  +0.81%
# 1             1,425,671,352  −0.02%
# 2               339,996,564  +0.50%
# 3               277,534,123  +0.74%
# 4               240,485,658  +1.98%
# ..                      ...     ...
# 469                   4,387  −0.07%
# 470                   3,791  +0.29%
# 471                   1,935  +0.05%
# 472                   1,893  +1.18%
# 473           8,045,311,448  +0.88%
#
# [474 rows x 6 columns]

# %%
df.to_csv("POPULATION_BY_COUNTRIES.csv")

# %%
Data = pd.read_csv("POPULATION_BY_COUNTRIES.csv")
new_data = Data.drop(columns ="Unnamed: 0")
new_data
# Out:
#                         Country / Area UN continentalregion[4]  \
# 0                                India                    Asia
# 1                             China[a]                    Asia
# 2                     United States[b]           North America
# 3                            Indonesia                    Asia
# 4                             Pakistan                    Asia
# ..                                 ...                     ...
# 469        Montserrat (United Kingdom)                Americas
# 470  Falkland Islands (United Kingdom)                Americas
# 471                 Niue (New Zealand)                 Oceania
# 472              Tokelau (New Zealand)                 Oceania
# 473                              World                     NaN
#
#     UN statisticalsubregion[4] Population(1 July 2022)  \
# 0                Southern Asia           1,417,173,173
# 1                 Eastern Asia           1,425,887,337
# 2             Northern America             338,289,857
# 3            Southeastern Asia             275,501,339
# 4                Southern Asia             235,824,863
# ..                         ...                     ...
# 469                  Caribbean                   4,390
# 470           Southern America                   3,780
# 471                  Polynesia                   1,934
# 472                  Polynesia                   1,871
# 473                        NaN           7,975,105,156
#
#     Population(1 July 2023)  Change
# 0             1,428,627,663  +0.81%
# 1             1,425,671,352  −0.02%
# 2               339,996,564  +0.50%
# 3               277,534,123  +0.74%
# 4               240,485,658  +1.98%
# ..                      ...     ...
# 469                   4,387  −0.07%
# 470                   3,791  +0.29%
# 471                   1,935  +0.05%
# 472                   1,893  +1.18%
# 473           8,045,311,448  +0.88%
#
# [474 rows x 6 columns]
